# %%
# !node --version
# Out:
# v16.10.0

# %%
from kaggle_environments import make

env = make("lux_ai_2021", configuration={"width": 24, "height": 24, "loglevel": 2, "annotations": True}, debug=True)
steps = env.run(['main.py', 'main.py'])
env.render(mode="ipython", width=1200, height=800)
# Out:
# Loading environment football failed: No module named 'gfootball'
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 34; cmd: bcity u_6
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 35; cmd: bcity u_6
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 36; cmd: bcity u_6
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 38; cmd: bcity u_12
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 38; cmd: bcity u_10
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 39; cmd: bcity u_13
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 39; cmd: bcity u_2
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 39; cmd: bcity u_10
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 40; cmd: bcity u_13
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 40; cmd: bcity u_2
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 40; cmd: bcity u_10
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 44; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 45; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 46; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 47; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 48; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 49; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 49; Unit u_14 collided when trying to move s to (16, 14)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 50; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 51; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 51; Unit u_22 collided when trying to move s to (16, 13)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 52; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 53; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 54; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile on non-empty resource tile; turn 55; cmd: bcity u_21
# [WARN] (match_1eLLSUnoZslE) - turn 55; Unit u_3 collided when trying to move w to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 55; Unit u_6 collided when trying to move e to (14, 10)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 56; Unit u_3 collided when trying to move w to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 56; Unit u_6 collided when trying to move e to (14, 10)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 57; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 57; Unit u_3 collided when trying to move w to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 57; Unit u_6 collided when trying to move e to (14, 10)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 58; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 58; Unit u_1 collided when trying to move n to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 58; Unit u_6 collided when trying to move e to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 58; Unit u_22 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 58; Unit u_32 collided when trying to move n to (16, 16)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 59; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 59; Unit u_1 collided when trying to move n to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 59; Unit u_6 collided when trying to move e to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 59; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 59; Unit u_25 collided when trying to move n to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 59; Unit u_22 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 59; Unit u_32 collided when trying to move n to (16, 16)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 60; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 60; Unit u_3 collided when trying to move w to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 60; Unit u_6 collided when trying to move e to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 60; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 60; Unit u_25 collided when trying to move n to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 60; Unit u_22 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 60; Unit u_2 collided when trying to move e to (16, 16)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 61; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 61; Unit u_3 collided when trying to move w to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 61; Unit u_6 collided when trying to move e to (14, 10)
# [WARN] (match_1eLLSUnoZslE) - turn 61; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 61; Unit u_25 collided when trying to move n to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 61; Unit u_22 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 61; Unit u_2 collided when trying to move e to (16, 16)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 62; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 80; turn 62; cmd: bcity u_2
# [WARN] (match_1eLLSUnoZslE) - turn 62; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 62; Unit u_25 collided when trying to move n to (16, 13)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 63; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 63; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 63; Unit u_25 collided when trying to move n to (16, 13)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile on non-empty resource tile; turn 64; cmd: bcity u_5
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 64; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 64; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 64; Unit u_25 collided when trying to move n to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 64; Unit u_22 collided when trying to move s to (16, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 64; Unit u_2 collided when trying to move e to (16, 16)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile on non-empty resource tile; turn 65; cmd: bcity u_5
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 65; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 65; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 65; Unit u_25 collided when trying to move n to (16, 13)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile on non-empty resource tile; turn 66; cmd: bcity u_5
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 66; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 66; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 66; Unit u_25 collided when trying to move n to (16, 13)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 67; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 67; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 67; Unit u_25 collided when trying to move n to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 67; Unit u_40 collided when trying to move e to (16, 14)
# [WARN] (match_1eLLSUnoZslE) - turn 67; Unit u_22 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 67; Unit u_44 collided when trying to move n to (16, 16)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 68; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 68; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 68; Unit u_25 collided when trying to move n to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 68; Unit u_24 collided when trying to move w to (16, 14)
# [WARN] (match_1eLLSUnoZslE) - turn 68; Unit u_22 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 68; Unit u_2 collided when trying to move e to (16, 15)
# [WARN] (match_1eLLSUnoZslE) - turn 68; Unit u_44 collided when trying to move n to (16, 16)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 69; cmd: bcity u_11
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_14 collided when trying to move w to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_25 collided when trying to move n to (16, 13)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_24 collided when trying to move w to (16, 14)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_22 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_2 collided when trying to move e to (16, 15)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_44 collided when trying to move n to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_29 collided when trying to move s to (15, 11)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_35 collided when trying to move n to (15, 11)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_40 collided when trying to move n to (15, 12)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_45 collided when trying to move s to (19, 8)
# [WARN] (match_1eLLSUnoZslE) - turn 69; Unit u_10 collided when trying to move n to (19, 8)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 70; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 87; turn 71; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 83; turn 72; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 79; turn 73; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 74; cmd: bcity u_25
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 75; cmd: bcity u_25
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 76; cmd: bcity u_25
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 77; cmd: bcity u_25
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 78; cmd: bcity u_25
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 79; cmd: bcity u_25
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 80; cmd: bcity u_25
# [WARN] (match_1eLLSUnoZslE) - turn 80; Unit u_14 collided when trying to move w to (16, 13)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 81; Unit u_14 collided when trying to move w to (16, 13)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 82; Unit u_22 collided when trying to move e to (17, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 82; Unit u_2 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 82; Unit u_24 collided when trying to move s to (17, 16)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 83; Unit u_22 collided when trying to move e to (17, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 83; Unit u_2 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 83; Unit u_24 collided when trying to move s to (17, 16)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 84; Unit u_22 collided when trying to move e to (17, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 84; Unit u_2 collided when trying to move s to (16, 16)
# [WARN] (match_1eLLSUnoZslE) - turn 84; Unit u_24 collided when trying to move s to (17, 16)
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 91; cmd: bcity u_25
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 92; cmd: bcity u_25
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 93; cmd: bcity u_25
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 94; cmd: bcity u_25
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 80; turn 99; cmd: bcity u_33
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 99; cmd: bcity u_52
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 102; cmd: bcity u_36
# [WARN] (match_1eLLSUnoZslE) - turn 102; Unit u_22 collided when trying to move e to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 102; Unit u_52 collided when trying to move n to (20, 17)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 103; Unit u_22 collided when trying to move e to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 103; Unit u_52 collided when trying to move n to (20, 17)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 104; Unit u_22 collided when trying to move e to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 104; Unit u_52 collided when trying to move n to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 104; Unit u_36 collided when trying to move e to (20, 18)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 105; Unit u_22 collided when trying to move e to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 105; Unit u_52 collided when trying to move n to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 105; Unit u_36 collided when trying to move e to (20, 18)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 106; cmd: bcity u_51
# [WARN] (match_1eLLSUnoZslE) - turn 106; Unit u_22 collided when trying to move e to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 106; Unit u_52 collided when trying to move n to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 106; Unit u_36 collided when trying to move e to (20, 18)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 107; cmd: bcity u_51
# [WARN] (match_1eLLSUnoZslE) - turn 107; Unit u_22 collided when trying to move e to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 107; Unit u_52 collided when trying to move n to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 107; Unit u_36 collided when trying to move e to (20, 18)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 108; Unit u_22 collided when trying to move e to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 108; Unit u_52 collided when trying to move n to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 108; Unit u_36 collided when trying to move e to (20, 18)
# test
# test
# [WARN] (match_1eLLSUnoZslE) - turn 109; Unit u_22 collided when trying to move e to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 109; Unit u_52 collided when trying to move n to (20, 17)
# [WARN] (match_1eLLSUnoZslE) - turn 109; Unit u_36 collided when trying to move e to (20, 18)
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 114; cmd: bcity u_33
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 115; cmd: bcity u_33
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 92; turn 115; cmd: bcity u_53
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 116; cmd: bcity u_33
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 90; turn 126; cmd: bcity u_11
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 0 tried to build CityTile with insufficient materials wood + coal + uranium: 95; turn 127; cmd: bcity u_11
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 154; cmd: bcity u_33
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 155; cmd: bcity u_33
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 156; cmd: bcity u_33
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 157; cmd: bcity u_33
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 158; cmd: bcity u_33
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 159; cmd: bcity u_33
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 160; cmd: bcity u_33
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 202; cmd: bcity u_74
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 203; cmd: bcity u_74
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 204; cmd: bcity u_74
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 205; cmd: bcity u_74
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 206; cmd: bcity u_74
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 207; cmd: bcity u_74
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 208; cmd: bcity u_74
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 85; turn 213; cmd: bcity u_80
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 243; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 244; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 245; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 246; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 247; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 248; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 249; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 250; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 251; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 252; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 253; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 254; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 255; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 256; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 257; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 258; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 259; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 260; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 261; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 262; cmd: bcity u_71
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 84; turn 270; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 85; turn 271; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 86; turn 272; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 87; turn 273; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 88; turn 274; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 89; turn 275; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 90; turn 276; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 91; turn 277; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 92; turn 278; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 93; turn 279; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 94; turn 280; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 96; turn 281; cmd: bcity u_41
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile with insufficient materials wood + coal + uranium: 98; turn 282; cmd: bcity u_41
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 285; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 286; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 287; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 288; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 289; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 290; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 291; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 292; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 293; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 294; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 295; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 296; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 297; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 298; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 299; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 300; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 301; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 302; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 303; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 304; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 305; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 306; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 307; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 308; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 309; cmd: bcity u_71
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 324; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 325; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 326; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 327; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 328; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 329; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 330; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 331; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 332; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 333; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 334; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 335; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 336; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 337; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 338; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 339; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 340; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 341; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 342; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 343; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 344; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 345; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 346; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 347; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 348; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 349; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 350; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 351; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 352; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 353; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 354; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 355; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 356; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 357; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 358; cmd: bcity u_71
# test
# test
# [WARN] (match_1eLLSUnoZslE) - Agent 1 tried to build CityTile on non-empty resource tile; turn 359; cmd: bcity u_71
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: true,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;11d4c870-2e33-11ec-9410-0c9d92c45293&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;width&quot;: 24,
#       &quot;height&quot;: 24,
#       &quot;loglevel&quot;: 2,
#       &quot;annotations&quot;: true,
#       &quot;episodeSteps&quot;: 361,
#       &quot;actTimeout&quot;: 3,
#       &quot;runTimeout&quot;: 1200,
#       &quot;mapType&quot;: &quot;random&quot;,
#       &quot;seed&quot;: 885987687
#     },
#     &quot;specification&quot;: {
#       &quot;action&quot;: {
#         &quot;description&quot;: &quot;Actions&quot;,
#         &quot;type&quot;: &quot;array&quot;,
#         &quot;default&quot;: 0
#       },
#       &quot;agents&quot;: [
#         2
#       ],
#       &quot;configuration&quot;: {
#         &quot;episodeSteps&quot;: {
#           &quot;description&quot;: &quot;Maximum number of steps the environment can run. Total is this number -1. One complete game is 360 steps&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;minimum&quot;: 2,
#           &quot;default&quot;: 361
#         },
#         &quot;actTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) to obtain an action from an agent.&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 3
#         },
#         &quot;runTimeout&quot;: {
#           &quot;description&quot;: &quot;Maximum runtime (seconds) of an episode (not necessarily DONE).&quot;,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 1200
#         },
#         &quot;parameters&quot;: {
#           &quot;description&quot;: &quot;Parameters for Lux AI 2021&quot;,
#           &quot;type&quot;: &quot;object&quot;
#         },
#         &quot;mapType&quot;: {
#           &quot;description&quot;: &quot;Map type to use&quot;,
#           &quot;type&quot;: &quot;string&quot;,
#           &quot;default&quot;: &quot;random&quot;
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;Width of map to generate&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;seed&quot;: {
#           &quot;description&quot;: &quot;Seed to use for episodes&quot;,
#           &quot;type&quot;: &quot;integer&quot;
#         },
#         &quot;annotations&quot;: {
#           &quot;description&quot;: &quot;Whether to enable debug annotations or not.&quot;,
#           &quot;type&quot;: &quot;boolean&quot;,
#           &quot;default&quot;: false
#         },
#         &quot;loglevel&quot;: {
#           &quot;description&quot;: &quot;Logging level of the game. 2 for warnings (e.g unit collisions, malformed actions), 1 for errors, 0 for none&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         }
#       },
#       &quot;info&quot;: {},
#       &quot;observation&quot;: {
#         &quot;remainingOverageTime&quot;: {
#           &quot;description&quot;: &quot;Total remaining banked time (seconds) that can be used in excess of per-step actTimeouts -- agent is disqualified with TIMEOUT status when this drops below 0.&quot;,
#           &quot;shared&quot;: false,
#           &quot;type&quot;: &quot;number&quot;,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 60
#         },
#         &quot;step&quot;: {
#           &quot;description&quot;: &quot;Current step within the episode.&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;minimum&quot;: 0,
#           &quot;default&quot;: 0
#         },
#         &quot;width&quot;: {
#           &quot;description&quot;: &quot;The width of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;height&quot;: {
#           &quot;description&quot;: &quot;The height of the map&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 12
#         },
#         &quot;reward&quot;: {
#           &quot;description&quot;: &quot;Current reward of the agent. Equal to number of city tiles * 10000 + number of units&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;default&quot;: 0
#         },
#         &quot;updates&quot;: {
#           &quot;description&quot;: &quot;List of update strings for agents to use and generate the observed state&quot;,
#           &quot;type&quot;: &quot;array&quot;,
#           &quot;shared&quot;: true
#         },
#         &quot;globalUnitIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;globalCityIDCount&quot;: {
#           &quot;description&quot;: &quot;Used purely to ensure state is the exact same including generated IDs&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;shared&quot;: true,
#           &quot;default&quot;: 0
#         },
#         &quot;player&quot;: {
#           &quot;description&quot;: &quot;Current player's index / team id&quot;,
#           &quot;type&quot;: &quot;integer&quot;,
#           &quot;defaults&quot;: [
#             0,
#             1
#           ]
#         }
#       },
#       &quot;reward&quot;: {
#         &quot;description&quot;: &quot;Reward of the agent. Equal to number of city tiles * 1000 + number of units&quot;,
#         &quot;type&quot;: [
#           &quot;integer&quot;,
#           &quot;null&quot;
#         ],
#         &quot;default&quot;: 0
#       }
#     },
#     &quot;steps&quot;: [
#       [
#         {
#           &quot;action&quot;: [],
#           &quot;reward&quot;: 0,
#           &quot;info&quot;: {},
#           &quot;observation&quot;: {
#             &quot;remainingOverageTime&quot;: 60,
#             &quot;step&quot;: 0,
#             &quot;width&quot;: 24,
#             &quot;height&quot;: 24,
#             &quot;reward&quot;: 0,
#             &quot;globalUnitIDCount&quot;: 2,
#             &quot;globalCityIDCount&quot;: 2,
#             &quot;player&quot;: 0,
#             &quot;updates&quot;: [
#               &quot;0&quot;,
#               &quot;24 24&quot;,
#               &quot;rp 0 0&quot;,
#               &quot;rp 1 0&quot;,
#               &quot;r wood 0 1 318&quot;,
#               &quot;r wood 0 2 393&quot;,
#               &quot;r wood 0 21 393&quot;,
#               &quot;r wood 0 22 318&quot;,
#               &quot;r uranium 5 5 329&quot;,
#               &quot;r uranium 5 6 328&quot;,
#               &quot;r wood 5 11 391&quot;,
#               &quot;r wood 5 12 391&quot;,
#               &quot;r uranium 5 17 328&quot;,
#               &quot;r uranium 5 18 329&quot;,
#               &quot;r uranium 6 4 341&quot;,
#               &quot;r uranium 6 5 305&quot;,
#               &quot;r uranium 6 6 327&quot;,
#               &quot;r wood 6 11 364&quot;,
#               &quot;r wood 6 12 364&quot;,
#               &quot;r uranium 6 17 327&quot;,
#               &quot;r uranium 6 18 305&quot;,
#               &quot;r uranium 6 19 341&quot;,
#               &quot;r uranium 7 5 308&quot;,
#               &quot;r uranium 7 18 308&quot;,
#               &quot;r coal 11 0 356&quot;,
#               &quot;r coal 11 23 356&quot;,
#               &quot;r wood 14 10 392&quot;,
#               &quot;r wood 14 13 392&quot;,
#               &quot;r wood 15 9 320&quot;,
#               &quot;r wood 15 14 320&quot;,
#               &quot;r wood 16 7 365&quot;,
#               &quot;r wood 16 8 363&quot;,
#               &quot;r
