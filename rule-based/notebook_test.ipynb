# %%
# %load_ext autoreload
# %autoreload 2

# %%
from kaggle_environments import make
import os
env = make("lux_ai_2021", debug=True, configuration={"annotations": True, "width":12, "height":12})
# Out:
# Loading environment football failed: No module named 'gfootball'

# %%
env.state
# Out:
# [{'action': [],
#   'reward': 0,
#   'info': {},
#   'observation': {'remainingOverageTime': 60,
#    'step': 0,
#    'width': 12,
#    'height': 12,
#    'reward': 0,
#    'globalUnitIDCount': 2,
#    'globalCityIDCount': 2,
#    'player': 0,
#    'updates': ['0',
#     '12 12',
#     'rp 0 0',
#     'rp 1 0',
#     'r wood 0 0 378',
#     'r wood 0 11 362',
#     'r wood 1 11 398',
#     'r uranium 2 9 317',
#     'r wood 2 10 800',
#     'r wood 2 11 800',
#     'r uranium 3 8 340',
#     'r uranium 3 9 339',
#     'r coal 4 2 409',
#     'r coal 4 3 411',
#     'r uranium 4 8 326',
#     'r wood 4 11 800',
#     'r coal 5 2 391',
#     'r coal 5 3 359',
#     'r coal 5 4 409',
#     'r coal 6 2 391',
#     'r coal 6 3 359',
#     'r coal 6 4 409',
#     'r coal 7 2 409',
#     'r coal 7 3 411',
#     'r uranium 7 8 326',
#     'r wood 7 11 800',
#     'r uranium 8 8 340',
#     'r uranium 8 9 339',
#     'r uranium 9 9 317',
#     'r wood 9 10 800',
#     'r wood 9 11 800',
# ...

# %%
dir(env)
# Out:
# ['_Environment__agent_runner',
#  '_Environment__get_shared_state',
#  '_Environment__get_state',
#  '_Environment__process_specification',
#  '_Environment__run_interpreter',
#  '_Environment__set_state',
#  '_Environment__state_schema',
#  '_Environment__state_schema_value',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__state_schema_0',
#  '__state_schema_1',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'agents',
#  'clone',
#  'configuration',
#  'debug',
#  'debug_print',
#  'done',
#  'html_renderer',
#  'id',
#  'info',
#  'interpreter',
#  'logs',
#  'name',
#  'play',
#  'pool',
#  'render',
#  'renderer',
#  'reset',
#  'run',
# ...

# %%
from kaggle_environments import make
import os
env = make("lux_ai_2021", debug=True, configuration={"annotations": True, "width":12, "height":12})
steps = env.run(["agent.py", "../LuxPythonEnvGym-main/kaggle_submissions/main_lux-ai-2021.py", ])
env.render(mode="ipython", width=1000, height=800)
# Out:
# Loading environment football failed: No module named 'gfootball'
# Traceback (most recent call last):
#   File "C:\Users\D\Anaconda3\lib\site-packages\kaggle_environments\agent.py", line 157, in act
#     action = self.agent(*args)
#   File "C:\Users\D\Anaconda3\lib\site-packages\kaggle_environments\agent.py", line 126, in callable_agent
#     args = args[:agent.__code__.co_argcount]
# AttributeError: type object 'AgentPolicy' has no attribute '__code__'
# Error: ['Traceback (most recent call last):\n', '  File "C:\\Users\\D\\Anaconda3\\lib\\site-packages\\kaggle_environments\\agent.py", line 157, in act\n    action = self.agent(*args)\n', '  File "C:\\Users\\D\\Anaconda3\\lib\\site-packages\\kaggle_environments\\agent.py", line 126, in callable_agent\n    args = args[:agent.__code__.co_argcount]\n', "AttributeError: type object 'AgentPolicy' has no attribute '__code__'\n"]
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
# ...
